# %%
# !pip install snowflake

# %%
# !pip install snowflake-ml-python

# %%
# !pip install snowflake-snowpark-python

# %%
# !pip install python-dotenv

# %% [markdown]
# # Connect to Snowflake

# %%
import os

# %%
# TO USE OUTSIDE GOOGLE COLAB
# from dotenv import load_dotenv
# from snowflake.snowpark.session import Session
# import os

# load_dotenv()

# connection_params = {
#     "account": os.getenv("SNOWFLAKE_ACCOUNT"),
#     "user": os.getenv("SNOWFLAKE_USER"),
#     "password": os.getenv("SNOWFLAKE_USER_PASSWORD"),
#     "role": os.getenv("SNOWFLAKE_ROLE"),
#     "database": os.getenv("SNOWFLAKE_DATABASE"),
#     "schema": os.getenv("SNOWFLAKE_SCHEMA"),
#     "warehouse": os.getenv("SNOWFLAKE_WAREHOUSE")
# }

# snowpark_session = Session.builder.configs(connection_params).create()

# %%
from google.colab import userdata  # for Google Colab authentication
from snowflake.snowpark.session import Session

connection_params = {
    "account": userdata.get('SNOWFLAKE_ACCOUNT'),
    "user": userdata.get('SNOWFLAKE_USER'),
    "password": userdata.get('SNOWFLAKE_USER_PASSWORD'),
    "role": userdata.get('SNOWFLAKE_ROLE'),
    "database": userdata.get('SNOWFLAKE_DATABASE'),
    "schema": userdata.get('SNOWFLAKE_SCHEMA'),
    "warehouse": userdata.get('SNOWFLAKE_WAREHOUSE')
}
snowpark_session = Session.builder.configs(connection_params).create()

# %%
snowpark_session

# %% [markdown]
# Test CORTEX LMM

# %%
from snowflake.cortex import Complete

print(Complete("mistral-large2", "how do snowflakes get their unique patterns?"))
# Out:
#  Snowflakes get their unique patterns through a complex process of crystallization that occurs as they form in the atmosphere. Here's a simplified explanation:
#
# 1. **Nucleation**: Snowflakes begin to form when a tiny particle in the atmosphere, such as a speck of dust, acts as a nucleus for ice crystals to grow around.
#
# 2. **Crystal Growth**: As the nucleus travels through the cloud, it encounters water vapor that freezes onto it, forming a tiny hexagonal prism of ice. This is the basic structure of a snowflake, which has six sides due to the molecular structure of water.
#
# 3. **Branching**: As the ice crystal grows, the six corners of the hexagon become unstable and start to branch out, forming the intricate arms of the snowflake. The exact pattern of this branching is influenced by the temperature and humidity within the cloud.
#
# ...

# %%
# !pip install llama-index
# !pip install llama-index-readers-github

# %% [markdown]
# # Get Data from Streamlit Documentation GitHub

# %%
import nest_asyncio
nest_asyncio.apply()

from llama_index.readers.github import GithubRepositoryReader, GithubClient

# %%
## FOR SKLEARN
# github_token = userdata.get('GITHUB_TOKEN')
# owner = "scikit-learn"
# repo = "scikit-learn"
# branch = "main"

# github_client = GithubClient(github_token=github_token, verbose=True)

# documents = GithubRepositoryReader(
#     github_client=github_client,
#     owner=owner,
#     repo=repo,
#     use_parser=False,
#     verbose=False,
#     filter_directories=(
#         ["doc"],
#         GithubRepositoryReader.FilterType.INCLUDE,
#     ),
#     filter_file_extensions=(
#         [
#             ".png",
#             ".jpg",
#             ".jpeg",
#             ".gif",
#             ".svg",
#             ".ico",
#             "json",
#             ".ipynb",
#         ],
#         GithubRepositoryReader.FilterType.EXCLUDE,
#     ),
# ).load_data(branch=branch)

# %%
github_token = userdata.get('GITHUB_TOKEN')
owner = "streamlit"
repo = "docs"
branch = "main"

github_client = GithubClient(github_token=github_token, verbose=True)

documents = GithubRepositoryReader(
    github_client=github_client,
    owner=owner,
    repo=repo,
    use_parser=False,
    verbose=False,
    filter_directories=(
        ["content/develop/concepts", "content/develop/tutorials"],
        GithubRepositoryReader.FilterType.INCLUDE,
    ),
    filter_file_extensions=(
        [
            ".png",
            ".jpg",
            ".jpeg",
            ".gif",
            ".svg",
            ".ico",
            "json",
            ".ipynb",
        ],
        GithubRepositoryReader.FilterType.EXCLUDE,
    ),
).load_data(branch=branch)

# %%
len(documents)
# Out:
# 72

# %%
documents[4]
# Out:
# Document(id_='11323bd8c4f23c02084d4dcb70ed9a888f2a684f', embedding=None, metadata={'file_path': 'content/develop/concepts/app-design/custom-classes.md', 'file_name': 'custom-classes.md', 'url': 'https://api.github.com/streamlit/docs/blob/main/content/develop/concepts/app-design/custom-classes.md'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='---\ntitle: Using custom Python classes in your Streamlit app\nslug: /develop/concepts/design/custom-classes\n---\n\n# Using custom Python classes in your Streamlit app\n\nIf you are building a complex Streamlit app or working with existing code, you may have custom Python classes defined in your script. Common examples include the following:\n\n- Defining a `@dataclass` to store related data within your app.\n- Defining an `Enum` class to represent a fixed set of options or values.\n- De
# ...

# %%
documents[4].text
# Out:
# '---\ntitle: Using custom Python classes in your Streamlit app\nslug: /develop/concepts/design/custom-classes\n---\n\n# Using custom Python classes in your Streamlit app\n\nIf you are building a complex Streamlit app or working with existing code, you may have custom Python classes defined in your script. Common examples include the following:\n\n- Defining a `@dataclass` to store related data within your app.\n- Defining an `Enum` class to represent a fixed set of options or values.\n- Defining custom interfaces to external services or databases not covered by [`st.connection`](/develop/api-reference/connections/st.connection).\n\nBecause Streamlit reruns your script after every user interaction, custom classes may be redefined multiple times within the same Streamlit session. This may result in unwanted effects, especially with class and instance comparisons. Read on to understand this common pitfall and how to avoid it.\n\nWe begin by covering some general-purpose patterns you can
# ...

# %% [markdown]
# # Turn Text into Python Code Format

# %%
import re

def markdown_to_python(markdown_text):
    # Split the text into lines
    lines = markdown_text.split('\n')
    print(lines)
    # Variables to track if we're inside a Python code block
    in_python_block = False
    result = []

    for line in lines:
        # Check for Python code block markers
        if line.strip().startswith('```python'):
            in_python_block = True
            continue
        elif line.strip() == '```' and in_python_block:
            in_python_block = False
            continue

        # Process the line
        if in_python_block:
            result.append(line)
        else:
            # Handle empty lines
            if not line.strip():
                result.append('#')
            else:
                # Preserve indentation
                leading_spaces = len(line) - len(line.lstrip())
                commented_line = ' ' * leading_spaces + '# ' + line.lstrip()
                result.append(commented_line)

    return '\n'.join(result)

# Example usage:
if __name__ == '__main__':
    markdown_text = """
# Title

This is a regular text.
<h1> makan tuh </h2>
```python
def hello():
    print("Hello")
```

```python def hai():
    print("hai")
```

More text here.
"""

    print(markdown_to_python(markdown_text))
# Out:
# ['', '# Title', '', 'This is a regular text.', '<h1> makan tuh </h2>', '```python', 'def hello():', '    print("Hello")', '```', '', '```python def hai():', '    print("hai")', '```', '', 'More text here.', '']
# #
# # # Title
# #
# # This is a regular text.
# # <h1> makan tuh </h2>
# def hello():
#     print("Hello")
# #
#     print("hai")
# #
# # More text here.
# #

# %%
from llama_index.core import Document

def transform_all_documents(documents):
    transformed_documents = []
    for d in documents:
        transformed_text = markdown_to_python(d.text)
        new_doc = Document(
            text=transformed_text,
            metadata=d.metadata
        )
        transformed_documents.append(new_doc)
    return transformed_documents

transformed_documents = transform_all_documents(documents)
# Out:
# ['---', 'title: Development concepts', 'slug: /develop/concepts', '---', '', '# Development concepts', '', 'This section gives you background on how different parts of Streamlit work.', '', '<TileContainer>', '', '<RefCard href="/develop/concepts/architecture" size="half">', '', "<h5>Streamlit's architecture and execution model</h5>", '', "Streamlit's execution model makes it easy to turn your scripts into beautiful, interactive web apps.", '', '- Understand how to run your app.', "- Understand Streamlit's execution and client-server model.", '- Understand the primary tools to work with Streamlit reruns.', '', '</RefCard>', '', '<RefCard href="/develop/concepts/multipage-apps" size="half">', '', '<h5>Multipage apps</h5>', '', 'Streamlit provides an automated way to build multipage apps through directory structure.', '', '- Learn how to structure and configure your multipage app.', '', '</RefCard>', '', '<RefCard href="/develop/concepts/design" size="half">', '', '<h5>App design consi
# ...

# %%
print(transformed_documents[4].text)
# Out:
# # ---
# # title: Using custom Python classes in your Streamlit app
# # slug: /develop/concepts/design/custom-classes
# # ---
# #
# # # Using custom Python classes in your Streamlit app
# #
# # If you are building a complex Streamlit app or working with existing code, you may have custom Python classes defined in your script. Common examples include the following:
# #
# # - Defining a `@dataclass` to store related data within your app.
# # - Defining an `Enum` class to represent a fixed set of options or values.
# # - Defining custom interfaces to external services or databases not covered by [`st.connection`](/develop/api-reference/connections/st.connection).
# #
# # Because Streamlit reruns your script after every user interaction, custom classes may be redefined multiple times within the same Streamlit session. This may result in unwanted effects, especially with class and instance comparisons. Read on to understand this common pitfall and how to avoid it.
# #
# ...

# %%
len(documents)
# Out:
# 72

# %%
print(transformed_documents[4].metadata)
# Out:
# {'file_path': 'content/develop/concepts/app-design/custom-classes.md', 'file_name': 'custom-classes.md', 'url': 'https://api.github.com/streamlit/docs/blob/main/content/develop/concepts/app-design/custom-classes.md'}

# %%
# import re

# def clean_up_text(content: str) -> str:
#   """
#   Remove unwanted characters and patterns in text input.

#   :param content: Text input.

#   :return: Cleaned version of original text input.
#   """

#   unwanted_patterns = ['---\nvisible: false','---','slug:']
#   for pattern in unwanted_patterns:
#     content = re.sub(pattern, "", content)

#   # Remove all slugs starting with a \ and stopping at the first space
#   content = re.sub(r'\\slug: [^\s]*', '', content)

#   # normalize whitespace
#   content = re.sub(r'\s+', ' ', content)
#   return content

# %%
# from llama_index.core import Document

# cleaned_documents = []
# for d in transformed_documents:
#     cleaned_text = clean_up_text(d.text)
#     new_doc = Document(
#         text=cleaned_text,
#         metadata=d.metadata
#     )
#     cleaned_documents.append(new_doc)

# %%
print(transformed_documents[5].text)
# Out:
# # ---
# # title: Dataframes
# # slug: /develop/concepts/design/dataframes
# # ---
# #
# # # Dataframes
# #
# # Dataframes are a great way to display and edit data in a tabular format. Working with Pandas DataFrames and other tabular data structures is key to data science workflows. If developers and data scientists want to display this data in Streamlit, they have multiple options: `st.dataframe` and `st.data_editor`. If you want to solely display data in a table-like UI, [st.dataframe](/develop/api-reference/data/st.dataframe) is the way to go. If you want to interactively edit data, use [st.data_editor](/develop/api-reference/data/st.data_editor). We explore the use cases and advantages of each option in the following sections.
# #
# # ## Display dataframes with st.dataframe
# #
# # Streamlit can display dataframes in a table-like UI via `st.dataframe` :
# #
# import streamlit as st
# import pandas as pd
#
# df = pd.DataFrame(
#     [
# ...

# %%
# !pip install llama-index-embeddings-huggingface

# %%
len(transformed_documents)
# Out:
# 72

# %% [markdown]
# # Code Chunking Function

# %%
import re

def chunk_transformed_text(text: str) -> dict:
    lines = text.split('\n')
    chunks = {}
    chunk_number = 1
    current_chunk = []
    comment_buffer = []
    last_line_was_code = False

    def is_code_block_start(line):
        patterns = [
            r'^\s*import\s+\w+',               # import statement
            r'^\s*from\s+\w+\s+import',        # from import
            r'^\s*def\s+\w+',                  # function definition
            r'^\s*class\s+\w+',                # class definition
            r'^\s*\w+\s*=\s*',                 # assignments
            r'^\s*@\w+',                       # decorators
            r'^\s*if\s+__name__\s*==',         # main block
        ]
        return any(re.match(pattern, line) for pattern in patterns)

    for i, line in enumerate(lines):
        stripped = line.strip()

        # Handle comments
        if stripped.startswith('#'):
            comment_buffer.append(line)
            last_line_was_code = False
            continue

        # Skip empty lines between sections
        if not stripped:
            if last_line_was_code:
                current_chunk.append(line)
            continue

        # If we hit a new code block
        if is_code_block_start(line) and not last_line_was_code:
            if current_chunk:
                chunks[chunk_number] = '\n'.join(current_chunk)
                chunk_number += 1
                current_chunk = []
            current_chunk.extend(comment_buffer)
            current_chunk.append(line)
            comment_buffer = []
            last_line_was_code = True
            continue

        # Continue current code block
        if last_line_was_code:
            current_chunk.append(line)
        # Start a new code block
        else:
            if current_chunk:
                chunks[chunk_number] = '\n'.join(current_chunk)
                chunk_number += 1
            current_chunk = comment_buffer + [line]
            comment_buffer = []
            last_line_was_code = True

    # Add final chunk
    if current_chunk:
        chunks[chunk_number] = '\n'.join(current_chunk)

    return chunks

# %%
text = transformed_documents[5].text

# %%
print(text)
# Out:
# # ---
# # title: Dataframes
# # slug: /develop/concepts/design/dataframes
# # ---
# #
# # # Dataframes
# #
# # Dataframes are a great way to display and edit data in a tabular format. Working with Pandas DataFrames and other tabular data structures is key to data science workflows. If developers and data scientists want to display this data in Streamlit, they have multiple options: `st.dataframe` and `st.data_editor`. If you want to solely display data in a table-like UI, [st.dataframe](/develop/api-reference/data/st.dataframe) is the way to go. If you want to interactively edit data, use [st.data_editor](/develop/api-reference/data/st.data_editor). We explore the use cases and advantages of each option in the following sections.
# #
# # ## Display dataframes with st.dataframe
# #
# # Streamlit can display dataframes in a table-like UI via `st.dataframe` :
# #
# import streamlit as st
# import pandas as pd
#
# df = pd.DataFrame(
#     [
# ...

# %%
chunks = chunk_transformed_text(text)
for i, chunk in chunks.items():
    print(f"Chunk {i}:")
    print(chunk)
    print("-" * 80)
# Out:
# Chunk 1:
# # ---
# # title: Dataframes
# # slug: /develop/concepts/design/dataframes
# # ---
# #
# # # Dataframes
# #
# # Dataframes are a great way to display and edit data in a tabular format. Working with Pandas DataFrames and other tabular data structures is key to data science workflows. If developers and data scientists want to display this data in Streamlit, they have multiple options: `st.dataframe` and `st.data_editor`. If you want to solely display data in a table-like UI, [st.dataframe](/develop/api-reference/data/st.dataframe) is the way to go. If you want to interactively edit data, use [st.data_editor](/develop/api-reference/data/st.data_editor). We explore the use cases and advantages of each option in the following sections.
# #
# # ## Display dataframes with st.dataframe
# #
# # Streamlit can display dataframes in a table-like UI via `st.dataframe` :
# #
# import streamlit as st
# import pandas as pd
#
# df = pd.DataFrame(
#     [
# ...

# %%
all_chunks = []
for doc in tqdm(transformed_documents, desc="Chunking documents"):
    chunks = chunk_transformed_text(doc.text)
    for chunk_id, chunk_text in chunks.items():
        all_chunks.append({
            'text': chunk_text,
            'metadata': {
                'file_path': doc.metadata.get('file_path', ''),
                'file_name': doc.metadata.get('file_name', ''),
                'url': doc.metadata.get('url', ''),
                'chunk_id': chunk_id
            }
        })
# Out:
# Chunking documents:   0%|          | 0/72 [00:00<?, ?it/s]

# %%
print(all_chunks[7]['text'])
# Out:
# #
# # ### Buttons to continue or control stages of a process
# #
# # Another alternative to nesting content inside a button is to use a value in `st.session_state` that designates the "step" or "stage" of a process. In this example, we have four stages in our script:
# #
# # 0. Before the user begins.
# # 1. User enters their name.
# # 2. User chooses a color.
# # 3. User gets a thank-you message.
# #
# # A button at the beginning advances the stage from 0 to 1. A button at the end resets the stage from 3 to 0. The other widgets used in stage 1 and 2 have callbacks to set the stage. If you have a process with dependant steps and want to keep previous stages visible, such a callback forces a user to retrace subsequent stages if they change an earlier widget.
# #
# import streamlit as st
#
# if 'stage' not in st.session_state:
#     st.session_state.stage = 0
#
# def set_state(i):
#     st.session_state.stage = i
#
# if st.session_state.stage == 0:
# ...

# %% [markdown]
# # Chunk Code and Store to Snowflake

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core.node_parser import SemanticSplitterNodeParser
import snowflake.connector
from tqdm.auto import tqdm
import numpy as np
import json

def chunk_and_store_to_snowflake(documents, connection_params, chunk_function):
    embed_model = HuggingFaceEmbedding("Snowflake/snowflake-arctic-embed-m")

    all_chunks = []
    for doc in tqdm(documents, desc="Chunking documents"):
        chunks = chunk_function(doc.text)
        for chunk_id, chunk_text in chunks.items():
            all_chunks.append({
                'text': chunk_text,
                'metadata': {
                    'file_path': doc.metadata.get('file_path', ''),
                    'file_name': doc.metadata.get('file_name', ''),
                    'url': doc.metadata.get('url', ''),
                    'chunk_id': chunk_id
                }
            })

    print(all_chunks[7]['text'])
    embeddings = []
    for chunk in tqdm(all_chunks, desc="Generating embeddings"):
        embedding = embed_model.get_text_embedding(chunk['text'])
        embeddings.append(json.dumps(embedding))  # Convert to JSON string

    snowflake_connector = snowflake.connector.connect(**connection_params)
    cursor = snowflake_connector.cursor()

    cursor.execute("""
    CREATE OR REPLACE TABLE streamlit_code_chunks (
        doc_text VARCHAR,
        file_path VARCHAR,
        file_name VARCHAR,
        url VARCHAR,
        chunk_id INTEGER,
        embedding VARCHAR  -- Changed to VARCHAR for JSON string
    )
    """)

    for chunk, embedding in tqdm(zip(all_chunks, embeddings), desc="Storing in Snowflake"):
        cursor.execute("""
        INSERT INTO streamlit_code_chunks (doc_text, file_path, file_name, url, chunk_id, embedding)
        VALUES (%s, %s, %s, %s, %s, %s)
        """, (
            chunk['text'],
            chunk['metadata']['file_path'],
            chunk['metadata']['file_name'],
            chunk['metadata']['url'],
            chunk['metadata']['chunk_id'],
            embedding
        ))
        snowflake_connector.commit()

    snowflake_connector.close()
    return all_chunks, embeddings

# %%
all_chunks, embeddings = chunk_and_store_to_snowflake(transformed_documents, connection_params, chunk_transformed_text)
# Out:
# Chunking documents:   0%|          | 0/72 [00:00<?, ?it/s]
# #
# # ### Buttons to continue or control stages of a process
# #
# # Another alternative to nesting content inside a button is to use a value in `st.session_state` that designates the "step" or "stage" of a process. In this example, we have four stages in our script:
# #
# # 0. Before the user begins.
# # 1. User enters their name.
# # 2. User chooses a color.
# # 3. User gets a thank-you message.
# #
# # A button at the beginning advances the stage from 0 to 1. A button at the end resets the stage from 3 to 0. The other widgets used in stage 1 and 2 have callbacks to set the stage. If you have a process with dependant steps and want to keep previous stages visible, such a callback forces a user to retrace subsequent stages if they change an earlier widget.
# #
# import streamlit as st
#
# if 'stage' not in st.session_state:
#     st.session_state.stage = 0
#
# def set_state(i):
#     st.session_state.stage = i
#
# ...

# %% [markdown]
# # Create Cortex Search

# %%
import os
import snowflake.connector
from tqdm.auto import tqdm

snowflake_connector = snowflake.connector.connect(**connection_params)

cursor = snowflake_connector.cursor()

# %% [markdown]
# ### CortexSearchRetriever

# %%
cortex_search_service_name = 'streamlit_code_search_svc'
snowflake_table_name = 'streamlit_code_chunks'

# %%
cursor.execute(f"""
CREATE OR REPLACE CORTEX SEARCH SERVICE {cortex_search_service_name}
ON doc_text
WAREHOUSE = COMPUTE_WH
TARGET_LAG = '1 hour'
AS
    SELECT
        doc_text,
    FROM {snowflake_table_name}
""")

# %%
print(f"""
CREATE OR REPLACE CORTEX SEARCH SERVICE {cortex_search_service_name}
ON doc_text
WAREHOUSE = COMPUTE_WH
TARGET_LAG = '1 hour'
AS
    SELECT
        doc_text,
    FROM {snowflake_table_name}
""")
# Out:
# CREATE OR REPLACE CORTEX SEARCH SERVICE streamlit_code_search_svc
# ON doc_text
# WAREHOUSE = COMPUTE_WH
# TARGET_LAG = '1 hour'
# AS
#     SELECT
#         doc_text,
#     FROM streamlit_code_chunks

# %%
import os
from snowflake.core import Root
from typing import List

class CortexSearchRetriever:

    def __init__(self, session: Session, limit_to_retrieve: int = 4):
        self._session = session
        self._limit_to_retrieve = limit_to_retrieve

    def retrieve(self, query: str) -> List[str]:
        root = Root(self._session)
        cortex_search_service = (
        root
        .databases['BADSCIENTIST_DEMO']
        .schemas['NOTEBOOKS']
        .cortex_search_services[f'{cortex_search_service_name}']
    )
        resp = cortex_search_service.search(
                query=query,
                columns=["doc_text"],
                limit=self._limit_to_retrieve,
            )

        if resp.results:
            return [curr["doc_text"] for curr in resp.results]
        else:
            return []

# %%
retriever = CortexSearchRetriever(session=snowpark_session, limit_to_retrieve=4)

retrieved_context = retriever.retrieve(query="How can I create button in streamlit?")

len(retrieved_context)
# Out:
# 4

# %%
retrieved_context
# Out:
# ["    # Streamlit will raise an Exception on trying to set the state of button\nst.button('Submit', key='my_button')",
#  "#\n# ### Toggle button\n#\n# If you want a button to work like a toggle switch, consider using [`st.checkbox`](/develop/api-reference/widgets/st.checkbox). Otherwise, you can use a button with a callback function to reverse a boolean value saved in `st.session_state`.\n#\n# In this example, we use `st.button` to toggle another widget on and off. By displaying [`st.slider`](/develop/api-reference/widgets/st.slider) conditionally on a value in `st.session_state`, the user can interact with the slider without it disappearing.\n#\nimport streamlit as st\n\nif 'button' not in st.session_state:\n    st.session_state.button = False\n\ndef click_button():\n    st.session_state.button = not st.session_state.button\n\nst.button('Click me', on_click=click_button)\n\nif st.session_state.button:",
# ...

# %%
print(retrieved_context[1])
# Out:
# #
# # ### Toggle button
# #
# # If you want a button to work like a toggle switch, consider using [`st.checkbox`](/develop/api-reference/widgets/st.checkbox). Otherwise, you can use a button with a callback function to reverse a boolean value saved in `st.session_state`.
# #
# # In this example, we use `st.button` to toggle another widget on and off. By displaying [`st.slider`](/develop/api-reference/widgets/st.slider) conditionally on a value in `st.session_state`, the user can interact with the slider without it disappearing.
# #
# import streamlit as st
#
# if 'button' not in st.session_state:
#     st.session_state.button = False
#
# def click_button():
#     st.session_state.button = not st.session_state.button
#
# st.button('Click me', on_click=click_button)
#
# if st.session_state.button:

# %% [markdown]
# ## RAG APP

# %%
import os
import snowflake.connector
from snowflake.core import Root
from snowflake.snowpark.context import get_active_session

# Constants
DB = "BADSCIENTIST_DEMO"
SCHEMA = "NOTEBOOKS"
SERVICE = f"{cortex_search_service_name}"
BASE_TABLE = f"BADSCIENTIST_DEMO.NOTEBOOKS.{snowflake_table_name}"

# Model options
MODELS = [
    "mistral-large2",
    "snowflake-arctic",
    "llama3-70b",
    "llama3-8b",
]

# %%
SERVICE
# Out:
# 'streamlit_code_search_svc'

# %%
class SnowflakeRagApp:
    def __init__(self, connection_params, model_name="mistral-large2", num_chunks=5):
        """Initialize the RAG application with Snowflake connection and parameters."""
        self.session = get_active_session()
        self.root = Root(self.session)
        self.model_name = model_name
        self.num_chunks = num_chunks
        self.search_column = self.get_service_search_column(SERVICE)

    def get_service_search_column(self, service_name):
        """Get search column for specific service."""
        try:
            desc_result = self.session.sql(
                f"DESC CORTEX SEARCH SERVICE {service_name};"
            ).collect()
            return desc_result[0]["search_column"]
        except Exception as e:
            raise ValueError(f"Error getting search column for service {service_name}: {str(e)}")

    def query_cortex_search(self, query, service_name=SERVICE):
        """Query the cortex search service and return context."""
        db, schema = self.session.get_current_database(), self.session.get_current_schema()

        cortex_search_service = (
            self.root.databases[db]
            .schemas[schema]
            .cortex_search_services[service_name]
        )

        context_documents = cortex_search_service.search(
            query, columns=[], limit=self.num_chunks
        )
        results = context_documents.results

        context_str = ""
        for i, r in enumerate(results):
            context_str += f"Context document {i+1}: {r[self.search_column]} \n\n"

        return context_str

    def complete(self, prompt):
        """Generate completion using Snowflake's language model."""
        return self.session.sql(
            "SELECT snowflake.cortex.complete(?,?)",
            (self.model_name, prompt)
        ).collect()[0][0]

    def create_prompt(self, user_question, context):
        """Create a prompt for the language model."""
        return f"""
        [INST]
        You are a helpful AI chat assistant with RAG capabilities. Use the context provided
        between <context> and </context> tags to provide a summary that addresses the user's
        question. Ensure the answer is coherent, concise, and directly relevant to the
        user's question.

        If the user asks a generic question which cannot be answered with the given context,
        just say "I don't know the answer to that question."

        Don't say things like "according to the provided context".

        <context>
        {context}
        </context>
        <question>
        {user_question}
        </question>
        [/INST]
        Answer:
        """

    def ask(self, question):
        """Process a user question and return the response."""
        # Get context from cortex search
        context = self.query_cortex_search(question)

        # Create prompt with context
        prompt = self.create_prompt(question, context)

        # Generate response
        response = self.complete(prompt)

        return {
            'question': question,
            'context': context,
            'response': response
        }

# %%
# Initialize the app
app = SnowflakeRagApp(connection_params)

# Ask individual questions
result = app.ask("How do I code button in streamlit?")
print(result['context'])
print(result['response'])
# Out:
# Context document 1: #
# # </Important>
# #
# # #### Option 1: Use a key for the button and put the logic before the widget
# #
# # If you assign a key to a button, you can condition code on a button's state by using its value in `st.session_state`. This means that logic depending on your button can be in your script before that button. In the following example, we use the `.get()` method on `st.session_state` because the keys for the buttons will not exist when the script runs for the first time. The `.get()` method will return `False` if it can't find the key. Otherwise, it will return the value of the key.
# #
# import streamlit as st
#
#
# Context document 2: #
# # ### Toggle button
# #
# # If you want a button to work like a toggle switch, consider using [`st.checkbox`](/develop/api-reference/widgets/st.checkbox). Otherwise, you can use a button with a callback function to reverse a boolean value saved in `st.session_state`.
# #
# ...

# %%
from IPython.display import display, Markdown

display(Markdown(result['response']))
# Out:
#  To code a button in Streamlit, you can use the `st.button` function. Here's a basic example:
#
# ```python
# import streamlit as st
#
# if st.button('Click me'):
#     st.write('Button was clicked!')
# ```
#
# In this example, when the button is clicked, it will display the text "Button was clicked!".
#
# If you want the button to retain its state (i.e., stay clicked), you can use `st.session_state`. Here's an example:
#
# ```python
# import streamlit as st
#
# if 'clicked' not in st.session_state:
#     st.session_state.clicked = False
#
# def click_button():
#     st.session_state.clicked = True
#
# st.button('Click me', on_click=click_button)
#
# if st.session_state.clicked:
#     st.write('Button was clicked!')
# ```
#
# In this case, the text "Button was clicked!" will remain visible even after the user interacts with other parts of the app.
